# %% [markdown]
# ## 데이터불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import mglearn
from matplotlib import font_manager, rc 

font_name=font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name() 
rc('font', family=font_name)

# %%
df_train = pd.read_csv("C:/users/yhg31/OneDrive/바탕 화면/데이터파일/2021 학술제 데이터/Subject_C.csv")
df_test = pd.read_csv("C:/users/yhg31/OneDrive/바탕 화면/데이터파일/2021 학술제 데이터/Subject_C_testset.csv")

# %%
df_train
# Out:
#       Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0         1    3573.336166  2067.827798       1.334973     2.294574
# 1         1    3569.424197  2063.871329       1.639684     2.573080
# 2         1    3570.767652  2064.654687       0.706498     2.613442
# 3         1    3569.156909  2065.357831       0.940101     2.563546
# 4         1    3567.536119  2063.997440       0.961830     2.374021
# ...     ...            ...          ...            ...          ...
# 2395      0    3579.006395  2068.655576       1.586043     3.942951
# 2396      0    3577.754330  2068.541012       1.348878     3.879034
# 2397      0    3577.100593  2067.995142       1.548819     4.276259
# 2398      0    3574.513352  2066.216075       1.723752     3.984821
# 2399      0    3572.398122  2065.238107       2.390633     2.759103
#
#       AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# ...

# %%
df_train["Class"].value_counts()
# Out:
# 1    800
# 2    800
# 0    800
# Name: Class, dtype: int64

# %%
col_list=df_train.columns[1:]
col_list1=[]
for i in range(len(col_list)):
    col_list1.append(col_list[i].split(" ")[0])
col_list1
set(col_list1)
# Out:
# {'AF3',
#  'AF4',
#  'F3',
#  'F4',
#  'F7',
#  'F8',
#  'FC5',
#  'FC6',
#  'O1',
#  'O2',
#  'P7',
#  'P8',
#  'T7',
#  'T8'}

# %%
X = df_train.iloc[:, 1:]
Y  = df_train.iloc[:, 0]

print(X.shape, Y.shape)
# Out:
# (2400, 112) (2400,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)
x_scaled = pd.DataFrame(x_scaled, columns=X.columns)
x_scaled
# Out:
#       AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  AF3 alpha std  \
# 0          0.169515     0.369550       0.473136    -0.359163      -0.620040
# 1         -0.288303    -0.368558       1.064341    -0.089091       0.180008
# 2         -0.131078    -0.222417      -0.746239    -0.049951       0.156572
# 3         -0.319583    -0.091240      -0.292999    -0.098336      -0.407732
# 4         -0.509265    -0.345031      -0.250840    -0.282122       0.065839
# ...             ...          ...            ...          ...            ...
# 2395       0.833103     0.523977       0.960265     1.239297       1.621033
# 2396       0.686574     0.502605       0.500115     1.177316      -0.778919
# 2397       0.610067     0.400769       0.888043     1.562513       0.252026
# 2398       0.307282     0.068871       1.227450     1.279900      -0.367055
# 2399       0.059736    -0.113576       2.521341     0.091299      -0.434977
#
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test  = train_test_split(x_scaled, Y, test_size=0.3)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (1680, 112)
# x_test shape: (720, 112)
# y_train shape: (1680,)
# y_test shape: (720,)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
knn_train_pred = knn.predict(x_train)
knn_test_pred = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print("D knn train 정확도 : {0:.3f}".format(accuracy_score(y_train, knn_train_pred)))
print("D knn test  정확도 : {0:.3f}".format(accuracy_score(y_test, knn_test_pred)))
# Out:
# D knn train 정확도 : 0.904
# D knn test  정확도 : 0.751

# %%
from sklearn.metrics import confusion_matrix

print("D KNN train\n", confusion_matrix(y_train, knn_train_pred))
print()
print("D KNN test\n", confusion_matrix(y_test, knn_test_pred))
# Out:
# D KNN train
#  [[532  12  16]
#  [ 37 502  21]
#  [ 58  18 484]]
#
# D KNN test
#  [[192  17  31]
#  [ 35 177  28]
#  [ 37  31 172]]

# %%
train_sc = []
test_sc = []
len_sc=[]

for k in range(1,10):
    k_knn = KNeighborsClassifier(n_neighbors=k)
    k_knn.fit(x_train, y_train)
    k_pred = k_knn.predict(x_test)
    train_sc.append(k_knn.score(x_train, y_train))
    test_sc.append((k_pred==y_test).mean())
    len_sc.append(k)

# %%
plt.figure(figsize=(10,5))
plt.plot(len_sc, test_sc)
plt.xlabel("n_neighbors")
plt.ylabel("accuracy")
plt.xticks(np.arange(1,9,step=1), size=20)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## 결과

# %%
df_test
# Out:
#      AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  AF3 alpha std  \
# 0      3568.155763  2062.071329       1.202268     2.825348       1.343916
# 1      3568.611785  2062.158824       0.807665     2.149917       0.737218
# 2      3570.473597  2065.758881       1.277113     1.959388       0.718773
# 3      3571.612568  2065.197847       0.751001     2.374316       0.388452
# 4      3573.342020  2066.813741       1.373842     2.725404       1.016329
# ..             ...          ...            ...          ...            ...
# 475    3580.266554  2069.890414       1.812120     3.738168       0.735718
# 476    3578.462843  2067.762354       1.310612     3.891495       0.845336
# 477    3573.877913  2066.994343       0.839764     2.361970       0.922445
# 478    3573.129417  2066.445913       1.027406     1.907314       1.373185
# 479    3571.731099  2065.153131       0.638391     1.474105       0.713962
#
# ...

# %%
test_scaled = scaler.fit_transform(df_test)
test_scaled = pd.DataFrame(test_scaled, columns=df_test.columns)
test_scaled
# Out:
#      AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  AF3 alpha std  \
# 0        -0.618695    -0.899286       0.319077     0.381127       0.808497
# 1        -0.533770    -0.872693      -0.533407    -0.571600      -0.593886
# 2        -0.187046     0.221490       0.480769    -0.840350      -0.636522
# 3         0.025064     0.050972      -0.655821    -0.255075      -1.400059
# 4         0.347139     0.542099       0.689738     0.240151       0.051279
# ..             ...          ...            ...          ...            ...
# 475       1.636692     1.477207       1.636575     1.668701      -0.597354
# 476       1.300788     0.830416       0.553138     1.884977      -0.343971
# 477       0.446938     0.596990      -0.464060    -0.272490      -0.165732
# 478       0.307546     0.430303      -0.058689    -0.913803       0.876153
# 479       0.047138     0.037381      -0.899100    -1.524864      -0.647643
#
# ...

# %%
df_test.insert(0,"Pred_Class",knn.predict(test_scaled),True)

# %%
df_test
# Out:
#      Pred_Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0             1    3568.155763  2062.071329       1.202268     2.825348
# 1             2    3568.611785  2062.158824       0.807665     2.149917
# 2             0    3570.473597  2065.758881       1.277113     1.959388
# 3             1    3571.612568  2065.197847       0.751001     2.374316
# 4             0    3573.342020  2066.813741       1.373842     2.725404
# ..          ...            ...          ...            ...          ...
# 475           2    3580.266554  2069.890414       1.812120     3.738168
# 476           2    3578.462843  2067.762354       1.310612     3.891495
# 477           0    3573.877913  2066.994343       0.839764     2.361970
# 478           2    3573.129417  2066.445913       1.027406     1.907314
# 479           1    3571.731099  2065.153131       0.638391     1.474105
#
#      AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# ...

# %%
# KNN으로 예측한 subject_C
df_test["Pred_Class"].value_counts()
# Out:
# 0    196
# 1    155
# 2    129
# Name: Pred_Class, dtype: int64

# %%
df_test.to_excel("Pred_subject_C.xlsx")
